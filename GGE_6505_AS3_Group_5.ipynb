
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# ref                            title               size  lastUpdated          downloadCount  voteCount  usabilityRating
# -----------------------------  ------------------  ----  -------------------  -------------  ---------  ---------------
# yeaseen564/weather-prediction  Weather_Prediction   1MB  2022-11-09 16:41:52              9          0  0.47058824

# %%
api.dataset_download_files('yeaseen564/weather-prediction',unzip=True)
api.dataset_download_files('imdevskp/corona-virus-report',unzip=True)

# %%
# %ls

# %%
data=pd.read_csv("country_wise_latest.csv" )

# %%
data.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
# 2                    6.17                23691           4282
# 3                    6.48                  884             23
# 4                   16.94                  749            201
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe
# 2              18.07                 Africa
# 3               2.60                 Europe
# 4              26.84                 Africa

# %%
data.shape
# Out:
# (187, 15)

# %%
Region_group=data.groupby("WHO Region")
Region_group['Deaths'].sum().sort_values()
# Out:
# WHO Region
# Western Pacific            8249
# Africa                    12223
# Eastern Mediterranean     38339
# South-East Asia           41349
# Europe                   211144
# Americas                 342732
# Name: Deaths, dtype: int64

# %%
Region_group.apply(lambda x: x[['Country/Region', 'Confirmed', 'Deaths']].sort_values(by = 'Deaths', ascending = False).iloc[:3,:])
# Out:
#                            Country/Region  Confirmed  Deaths
# WHO Region
# Africa                154    South Africa     452529    7067
#                       2           Algeria      27973    1163
#                       124         Nigeria      41180     860
# Americas              173              US    4290259  148011
#                       23           Brazil    2442375   87618
#                       111          Mexico     395489   44022
# Eastern Mediterranean 81             Iran     293606   15912
#                       128        Pakistan     274289    5842
#                       52            Egypt      92482    4652
# Europe                177  United Kingdom     301708   45844
#                       85            Italy     246286   35112
#                       61           France     220352   30212
# South-East Asia       79            India    1480073   33408
#                       80        Indonesia     100303    4838
#                       13       Bangladesh     226225    2965
# Western Pacific       36            China      86783    4656
#                       133     Philippines      82040    1945
#                       87            Japan      31142     998

# %%
Region_group.apply(lambda x: x['Deaths'].describe()).sort_values(by=['mean'])
# Out:
# Deaths                 count         mean           std   min    25%    50%  \
# WHO Region
# Africa                  48.0   254.645833   1025.735615   0.0  11.75   47.5
# Western Pacific         16.0   515.562500   1220.355848   0.0   0.00   14.5
# Eastern Mediterranean   22.0  1742.681818   3603.198597  11.0  67.50  330.5
# Europe                  56.0  3770.428571   9289.098725   0.0  66.75  398.0
# South-East Asia         10.0  4134.900000  10420.727224   0.0   7.25   31.5
# Americas                35.0  9792.342857  29104.886288   0.0   9.00  115.0
#
# Deaths                     75%       max
# WHO Region
# Africa                  105.25    7067.0
# Western Pacific         200.25    4656.0
# Eastern Mediterranean  1131.75   15912.0
# Europe                 1686.75   45844.0
# South-East Asia        2238.25   33408.0
# Americas               2853.00  148011.0
